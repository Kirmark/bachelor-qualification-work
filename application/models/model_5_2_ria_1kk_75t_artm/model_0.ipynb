# %%
# %matplotlib inline
import glob
import os
import matplotlib.pyplot as plt
import datetime

import artm

# Адрес, по которому находятся данные
BATCH_ADRESS = '../batches_news_ria_1kk'

# Вывод версии BigARTM
print(artm.version())
# Out:
# 0.10.0

# %%
def print_now():
    print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M"))

# %%
# Установка адреса, по которому находятся данные
batch_vectorizer = artm.BatchVectorizer(
    data_path=BATCH_ADRESS, data_format='batches'
)

# %%
#MODE = 'new'
MODE = 'load'

# Устанавливается название словаря для модели
dictionary_address = BATCH_ADRESS + '/dictionary.dict'

# Инициализация словоря для модели
dictionary = artm.Dictionary()

if MODE == 'new':
    print_now()

    # Удаление словаря, оставшегося после предыдущих запусков
    if os.path.isfile(dictionary_address):
        os.remove(dictionary_address)

    # Сохранение словаря в файл
    dictionary.gather(data_path=batch_vectorizer.data_path)
    dictionary.save(dictionary_path=dictionary_address)
    
    print_now()

# Загрузка словаря из файла
dictionary.load(dictionary_path=dictionary_address)
print(
    '{:>7}'.format(dictionary.__dict__['_master'].get_info().dictionary[0].num_entries),
    "- количество слов в словаре"
)

# Фильтрация

# Убираются редкие слова по всей коллекции
# Слово встречается во всей коллекции больше чем n раз
dictionary.filter(min_tf=10)
print(
    '{:>7}'.format(dictionary.__dict__['_master'].get_info().dictionary[0].num_entries),
    "- количество слов в словаре после фильтрации по min_tf", 
)

# Убираются частые слова по всей коллекции
# Слово встречается во всей коллекции меньше чем n раз
dictionary.filter(max_tf=10000)
print(
    '{:>7}'.format(dictionary.__dict__['_master'].get_info().dictionary[0].num_entries),
    "- количество слов в словаре после фильтрации по max_tf", 
)

# Убираются слова, которые попадаются меньше чем в n процентов документов
dictionary.filter(min_df_rate=0.0001)
print(
    '{:>7}'.format(dictionary.__dict__['_master'].get_info().dictionary[0].num_entries),
    "- количество слов в словаре после фильтрации по min_df_rate", 
)

# Убираются слова, которые попадаются больше чем в n процентов документов
dictionary.filter(max_df_rate=0.5)
print(
    '{:>7}'.format(dictionary.__dict__['_master'].get_info().dictionary[0].num_entries),
    "- количество слов в словаре после фильтрации по max_df_rate", 
)
# Out:
#  461281 - количество слов в словаре
#  123303 - количество слов в словаре после фильтрации по min_tf
#  120314 - количество слов в словаре после фильтрации по max_tf
#   32265 - количество слов в словаре после фильтрации по min_df_rate
#   32265 - количество слов в словаре после фильтрации по max_df_rate

# %%
def new_default_model(topic_count, dictionary):
    
    # Создание модели
    model_artm = artm.ARTM(
        # Названия тем
        topic_names=['topic_{0:0>3}'.format(i) for i in range(topic_count)], 
        # Разрешается хранить матрицу theta в памяти
        cache_theta=True,
        # Фиксация seed для воспроизвдимости результатов
        seed=-1,
        # Настройка - сколько раз обрабатывать каждый документ
        num_document_passes=1,
        # Модальности
        #class_ids={'text': 1.0},
    )

    # Инициализация модели
    model_artm.initialize(dictionary=dictionary)

    # Установка отслеживаемых параметров
    # Перплексия (чем она меньше тем лучше)
    model_artm.scores.add(artm.PerplexityScore(name='PerplexityScore'))
    # Разреженность матрицы Phi (доля почти нулевых значений)
    model_artm.scores.add(artm.SparsityPhiScore(name='SparsityPhiScore'))
    # Разреженность матрицы Theta (доля почти нулевых значений)
    model_artm.scores.add(artm.SparsityThetaScore(name='SparsityThetaScore'))
    # Анализ самых используемых слов по темам
    model_artm.scores.add(artm.TopTokensScore(name='TopTokensScore', num_tokens=10))
    # Анализ ядра тем на контраст и чистоту
    model_artm.scores.add(artm.TopicKernelScore(name='TopicKernelScore'))
    #model_artm.scores.add(artm.TopicKernelScore(name='TopicKernelScore', probability_mass_threshold=0.3))
    
    return model_artm

# %%
def model_print_results(model_artm):
    
    # Графики
    
    fig = plt.figure(figsize=(15, 20))

    ax = plt.subplot2grid((4,3), (0,0), colspan = 1, rowspan = 1,  fig=fig)
    ax.plot(model_artm.score_tracker["PerplexityScore"].value, color='tab:blue')
    ax.set_xlabel('Iterations count')
    ax.set_ylabel('PerplexityScore')
    ax.grid(True)

    ax = plt.subplot2grid((4,3), (0,1), colspan = 1, rowspan = 1,  fig=fig)
    ax.plot(model_artm.score_tracker["SparsityPhiScore"].value, color='tab:blue')
    ax.set_xlabel('Iterations count')
    ax.set_ylabel('SparsityPhiScore')
    ax.grid(True)
    ax.set_ylim([0,1])

    ax = plt.subplot2grid((4,3), (0,2), colspan = 1, rowspan = 1,  fig=fig)
    ax.plot(model_artm.score_tracker["SparsityThetaScore"].value, color='tab:blue')
    ax.set_xlabel('Iterations count')
    ax.set_ylabel('SparsityThetaScore')
    ax.grid(True)
    ax.set_ylim([0,1])


    ax = plt.subplot2grid((4,3), (1,0), colspan = 1, rowspan = 1,  fig=fig)
    ax.plot(model_artm.score_tracker["TopicKernelScore"].average_contrast, color='tab:blue')
    ax.set_xlabel('Iterations count')
    ax.set_ylabel('TopicKernelScore_average_contrast')
    ax.grid(True)
    ax.set_ylim([0,1])

    ax = plt.subplot2grid((4,3), (1,1), colspan = 2, rowspan = 1,  fig=fig)
    my_contrast_dictionary = model_artm.score_tracker['TopicKernelScore'].last_contrast
    ax.bar(my_contrast_dictionary.keys(), my_contrast_dictionary.values(), 0.5, color='tab:blue')
    #ax.set_xlabel('//')
    #ax.set_ylabel('//')
    ax.grid(True)
    ax.tick_params(axis='x', rotation=90)
    ax.set_ylim([0,1])


    ax = plt.subplot2grid((4,3), (2,0), colspan = 1, rowspan = 1,  fig=fig)
    ax.plot(model_artm.score_tracker['TopicKernelScore'].average_purity, color='tab:blue')
    ax.set_xlabel('Iterations count')
    ax.set_ylabel('TopicKernelScore_average_purity')
    ax.grid(True)
    ax.set_ylim([0,1])

    ax = plt.subplot2grid((4,3), (2,1), colspan = 2, rowspan = 1,  fig=fig)
    my_purity_dictionary = model_artm.score_tracker['TopicKernelScore'].last_purity
    ax.bar(my_purity_dictionary.keys(), my_purity_dictionary.values(), 0.5, color='tab:blue')
    #ax.set_xlabel('//')
    #ax.set_ylabel('//')
    ax.grid(True)
    ax.tick_params(axis='x', rotation=90)
    ax.set_ylim([0,1])


    ax = plt.subplot2grid((4,3), (3,0), colspan = 1, rowspan = 1,  fig=fig)
    my_average_size = model_artm.score_tracker['TopicKernelScore'].average_size
    ax.plot(my_average_size, color='tab:blue')
    ax.plot([model_artm.phi_.shape[0]/model_artm.num_topics for i in range(len(my_average_size))], color='tab:orange')
    ax.set_xlabel('Iterations count')
    ax.set_ylabel('TopicKernelScore_average_size')
    ax.grid(True)
    ax.set_ylim([0,ax.get_ylim()[1]])

    ax = plt.subplot2grid((4,3), (3,1), colspan = 2, rowspan = 1,  fig=fig)
    my_size_dictionary = model_artm.score_tracker['TopicKernelScore'].last_size
    ax.bar(my_size_dictionary.keys(), my_size_dictionary.values(), 0.5, color='tab:blue')
    ax.plot([model_artm.phi_.shape[0]/model_artm.num_topics for i in range(model_artm.num_topics)], color='tab:orange')
    #ax.set_xlabel('//')
    #ax.set_ylabel('//')
    ax.grid(True)
    ax.tick_params(axis='x', rotation=90)

    plt.show()
    
    
    # Конечные значения
    
    print("PerplexityScore:", model_artm.score_tracker["PerplexityScore"].last_value)
    print("SparsityPhiScore:", model_artm.score_tracker["SparsityPhiScore"].last_value)
    print("SparsityThetaScore:", model_artm.score_tracker["SparsityThetaScore"].last_value)
    print()
    print("TopicKernelScore_average_contrast:", model_artm.score_tracker["TopicKernelScore"].last_average_contrast)
    print("TopicKernelScore_average_purity:", model_artm.score_tracker['TopicKernelScore'].last_average_purity)
    print("TopicKernelScore_average_size:", model_artm.score_tracker['TopicKernelScore'].last_average_size)
    
    print()
    
    
    # Главные слова в темах
    
    print("TopTokensScore:")
    topic_list = list(model_artm.score_tracker['TopTokensScore'].last_tokens.keys())
    for topic_name in topic_list:
        print(topic_name + ': ', end='')
        for token_name in model_artm.score_tracker['TopTokensScore'].last_tokens[topic_name]:
            print(token_name, end=' ')
        print()

# %%
params = {
    'topic_count': 75,
    'SparsePhi': {
        'name': 'SparsePhi',
        'tau': -5,
    },
    'SparseTheta': {
        'name': 'SparseTheta',
        'tau': -3,
    },
    'DecorrelatorPhi': {
        'name': 'DecorrelatorPhi',
        'tau': 25_000_000,
    },
}

# %%
# Создание базовой пустой модели
model_artm = new_default_model(params['topic_count'], dictionary)
model_artm.load('news_model_plsa')

# %%
# Модель 0_1
# Запуск регуляризатора SparsePhi

# Регуляризатор SparsePhi
# Создание регуляризатора, если он уже не создан
if params['SparsePhi']['name'] not in list(model_artm.regularizers.data):
    model_artm.regularizers.add(artm.SmoothSparsePhiRegularizer(name=params['SparsePhi']['name']))
# Настройка регуляризатора
model_artm.regularizers[params['SparsePhi']['name']].tau = params['SparsePhi']['tau']

# Обучение модели
print_now()
model_artm.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=25)
print_now()

# Вывод метрик модели
model_print_results(model_artm)

# Сохранение модели
model_artm.save("news_model_0_1")
model_artm_0_1 = model_artm.clone()

# Выполняется примерно 1.2 часа
# Out:
# 2019-06-07 16:04

# %%
# Загрузка модели
model_artm = new_default_model(params['topic_count'], dictionary)
model_artm.load("news_model_0_1")

# %%
# Модель 0_2
# Запуск регуляризатора SparseTheta к уже включенному SparsePhi

# Регуляризатор SparsePhi
# Создание регуляризатора, если он уже не создан
if params['SparsePhi']['name'] not in list(model_artm.regularizers.data):
    model_artm.regularizers.add(artm.SmoothSparsePhiRegularizer(name=params['SparsePhi']['name']))
# Настройка регуляризатора
model_artm.regularizers[params['SparsePhi']['name']].tau = params['SparsePhi']['tau']

# Регуляризатор SparseTheta
# Создание регуляризатора если он уже не создан
if params['SparseTheta']['name'] not in list(model_artm.regularizers.data):
    model_artm.regularizers.add(artm.SmoothSparseThetaRegularizer(name=params['SparseTheta']['name']))
# Настройка регуляризатора
model_artm.regularizers[params['SparseTheta']['name']].tau = params['SparseTheta']['tau']

# Обучение модели
print_now()
model_artm.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=5)
print_now()

# Вывод метрик модели
model_print_results(model_artm)

# Сохранение модели
model_artm.save("news_model_0_2")
model_artm_0_2 = model_artm.clone()

# Выполняется примерно
# Out:
# 2019-06-07 16:11
# 2019-06-07 16:27
# PerplexityScore: 5.129624843597412
# SparsityPhiScore: 0.9827648401260376
# SparsityThetaScore: 0.9623265862464905
#
# TopicKernelScore_average_contrast: 0.7897613048553467
# TopicKernelScore_average_purity: 0.9544083476066589
# TopicKernelScore_average_size: 495.1199951171875
#
# TopTokensScore:
# topic_000: яндекс лукойл катер почтовый компьютерный поисковый хакер акватория обновление рыбак
# topic_001: блогер контент соцсеть милан нарышкин смоленск вконтакте цифровой персональный качиньский
# topic_002: тайм томь армеец штрафной довольный таблица турнирный вничью подопечный арбитр
# topic_003: паралимпийский фунт мокнуть мурманск стерлинг перо романов ролик хост фонтан
# topic_004: героин наркотический фскн ростелеком теннисист приднестровье ростуризм кишинев сбыт испанец
# topic_005: кострома костромской астрахань шувалов скульптура крест горнолыжный астраханский долина мурманский
# topic_006: сериал оскар сниматься персонаж комедия книжный мали сценарист любимый каннский
# topic_007: магнитский ивановский мемориал европарламент иваново уплата смертник донор михайловский владикавказ
# topic_008: глонасс славянск рига протон нафтогаз скидка омбудсмен экспресс самоубийство латвийский
# topic_009: мода дизайнер фрагмент метеорит кэмерон архив учебник придумывать фамилия страх
# topic_010: уран магатэ шестерка снаряд гаити обстреливать опек ополчение обогащение посредник
# topic_011: теннисистка теннис призовой чемпионка игорный издательство галина записывать спортсменка ракетка
# topic_012: эколог мусор летчик оренбургский нация минприроды оренбург грант душанбе охранять
# topic_013: сербский йемен белград серб телескоп соколов астроном кошка косовский салех
# topic_014: венгрия петров ввоз баку молочный гонщик малайзия босния кластер герцеговина
# topic_015: бивалютный нефтепродукт антимонопольный коридор грунт интервенция спаллетти кызыл фобос диапазон
# topic_016: портрет такси ездить ньюсмейкер визуальный замок бабушка осенний пожилой бесплатно
# topic_017: зерно усыновление карелия приемный сельскохозяйственный урожай продовольственный транзит панк усыновлять
# topic_018: икона церковный ульяновский митрополит князь верующий ульяновск христианин епархия внуково
# topic_019: эбола лихорадка труппа драматический репетиция училище стих гастроль госпиталь мариинский
# topic_020: мясо сексуальный сенат республиканец блюдо баскетболист интеко овощ кухня баскетбол
# topic_021: меркель гонконг курение напиток пиво канцлер ангел торговаться сигарета секция
# topic_022: нобелевский шведский филиппины физика стокгольм русгидро ассанж утилизация спектр германский
# topic_023: клетка коми организм жара растение молоко исследователь переработка концентрация запах
# topic_024: пляж санкционный рязанский меморандум взаимный акула волк снятие неприемлемый разногласие
# topic_025: арктический марс прибор тихий эпицентр зонд астероид луна освоение летный
# topic_026: принц королева свадьба ливан яйцо ватикан елизавета уильям престол миллер
# topic_027: космодром пуск норвежский планшет югра оснащать баллистический байконур осло зенитный
# topic_028: мубарак мурси дольщик застройщик ратификация башкирия металл обманывать хосни мухаммед
# topic_029: хоть саратов пусть спокойно вроде нравиться задание удивлять зачем математика
# topic_030: колумбия изнасилование воин царь титов еврей цивилизация религия национальность мадонна
# topic_031: ереван армянский одкб коллективный кабул союзный талиб карабах сопредседатель постсоветский
# topic_032: жириновский коммунист единоросс эсер палестинец голосовать депутатский созыв палестина газа
# topic_033: сахалин циклон отключение подтопление бедствие крымск электричество электроснабжение загрязнение порыв
# topic_034: пристав респондент должник лекарственный вциом материнский азиатский сертификат никель башнефть
# topic_035: цирк псковский масло псков вкус цирковой игрушка соль цветной аттракцион
# topic_036: цитирование перепечатка мосгордума васильев садовый заммэра пушкинский переть кавказский арбат
# topic_037: болотный калининградский тула маркин пономарев филин вологодский вологда бандит удалец
# topic_038: бурятия чайковский дирижер филармония ансамбль симфонический консерватория забайкальский чита юбилейный
# topic_039: портфель менеджмент заемщик гостиничный страховщик дочка ведомость заплатить выкупать дочерний
# topic_040: мечеть словакия эштон металлург дипломатия кемеровский кузбасс салават бирюлево кэтрин
# topic_041: тюменский ответчик тюмень арбитраж взыскивать ледокол реестр оспаривать макаров заявитель
# topic_042: барс ирландия котировка португалия нападающий брянский тренерский фанат капитализация атланта
# topic_043: реабилитация камаз ставропольский ставрополь похищение многодетный пятигорск микроавтобус ставрополье уборка
# topic_044: фукусима перепись клинтон радиоактивный керри химоружие радиация цунами радиационный дошкольный
# topic_045: адмирал пират свинья африканский черноморский литр танкер верфь подлодка судостроительный
# topic_046: универсиада мутко декларация астана несанкционированный пропаганда увольнение генпрокурор химкинский некоммерческий
# topic_047: анжи чешский рельс марш многоквартирный сходить жилец курский терек тестирование
# topic_048: фифа экспо факс саркозить уефа доба миусский олланд битва мистраль
# topic_049: теплоход затонуть повстанец муамар триполи мексиканский булгария лошадь дания бенгази
# topic_050: берлускони евровидение счетный уралкалий специальность владислав вино заслуга герман накопительный
# topic_051: грипп инфекция куба тигр чавес заболевать ипотека онищенко кубинский профилактика
# topic_052: уголь кадыров священник корейский грозный шахтер пхеньян угольный сход южнокорейский
# topic_053: условно автоваз отбывать кассационный злоупотребление пожизненный вымогательство апелляция обвинительный вынесение
# topic_054: минобрнаука дворкович ингушетия работодатель критерий одесса педагогический профильный набор аркадий
# topic_055: интернат волонтер комбинат занятость муниципалитет социально весенний воспитанник автомат самоуправление
# topic_056: радикал фотограф изображение коктейль марафон молотов евромайдан схватка арсений бостон
# topic_057: ураган пакистанский педагог попов эрмитаж еспча луценко каникулы беспилотник ожог
# topic_058: малайзийский лужники роснано госпереворот февральский минский таллин эстонский самопровозглашенный атлетика
# topic_059: лыжный чехов биатлон ванкувер мультфильм драма трейлер дисциплина михалков биатлонист
# topic_060: юкос водоснабжение труба амур шереметьево депозит анкара отзыв отзывать трубопровод
# topic_061: бангкок саакашвили вещание фурсенко заработный инаугурация стросс таиландский паром иванишвили
# topic_062: врезаться причинение пьяный иномарка опьянение избиение руль встречный березовский неосторожность
# topic_063: реставрация усадьба застройка музейный подрядчик проектирование пешеходный постройка возведение фасад
# topic_064: тунис аравия бишкек катар извержение бакиев дубай пепел волнение переворот
# topic_065: перевозчик иракский платный задержка росавиация багдад трансаэро летать минтранс скоростной
# topic_066: хакасия русала психолог антонов шотландия противопожарный потушить абакан комплект черногория
# topic_067: луганск митинговать колонна боец протестовать украинец танк белгородский плавание каток
# topic_068: сноудена сноудно эдвард убежище боксер яковлев общежитие федоров бокс секретный
# topic_069: синоптик теплый елка гидрометцентр атмосферный нальчик миллиметр столб ноль барнаул
# topic_070: фигурный пасе гараж фигурист тоннель юнеско плющенко страсбург стоянка крейсер
# topic_071: присяжный банда удмуртия голодовка экстрадиция кража вердикт охранник ижевск козлов
# topic_072: камчатский камчатка магадан казнь магаданский якутск прогреметь нигерия смертный обломок
# topic_073: иена полонский подорожать кредитование центробанк рейтинговый дефолт миграционный росстат выражение
# topic_074: барселона рогозин манчестер арсенал реал абонент челси модуль астронавт мегафон

# %%
phi = model_artm.phi_
phi

# %%
theta = model_artm.get_theta()
theta
# Out:
#              428000    428001    428002    428003    428004    428005  \
# topic_000  0.014736  0.014028  0.015700  0.014413  0.007556  0.013513
# topic_001  0.012902  0.014848  0.015771  0.011966  0.011847  0.015381
# topic_002  0.011596  0.014222  0.011924  0.012497  0.010180  0.012633
# topic_003  0.013603  0.013667  0.014943  0.011876  0.011979  0.013637
# topic_004  0.012239  0.011242  0.015018  0.013441  0.020197  0.017364
# topic_005  0.012033  0.010119  0.011767  0.011403  0.015300  0.015640
# topic_006  0.011479  0.013640  0.010102  0.011944  0.017770  0.009701
# topic_007  0.013530  0.012973  0.014924  0.013484  0.008464  0.014448
# topic_008  0.015433  0.012317  0.014325  0.012826  0.012174  0.013584
# topic_009  0.014923  0.010232  0.013403  0.014196  0.014449  0.014644
# topic_010  0.011446  0.012569  0.010349  0.013288  0.016929  0.009859
# topic_011  0.013450  0.011823  0.015702  0.014288  0.016679  0.012291
# topic_012  0.012915  0.016206  0.013094  0.013352  0.015748  0.012315
# topic_013  0.014579  0.012567  0.016361  0.010492  0.023247  0.011995
# topic_014  0.012363  0.011770  0.013127  0.012800  0.012776  0.013157
# topic_015  0.013254  0.016845  0.013995  0.013183  0.018455  0.013730
# topic_016  0.013678  0.014795  0.015199  0.013222  0.015225  0.012689
# topic_017  0.011595  0.009183  0.012891  0.015517  0.013355  0.014911
# topic_018  0.014274  0.016982  0.012685  0.011596  0.011275  0.011738
# topic_019  0.013468  0.016136  0.014259  0.012893  0.018641  0.014547
# topic_020  0.012399  0.012956  0.013473  0.016286  0.009892  0.013606
# topic_021  0.012880  0.012196  0.013408  0.013581  0.008703  0.015398
# topic_022  0.013322  0.013704  0.012925  0.016196  0.016723  0.013110
# topic_023  0.012580  0.012354  0.010891  0.014874  0.013537  0.012857
# topic_024  0.013605  0.011972  0.012308  0.010548  0.012369  0.013394
# topic_025  0.014337  0.014155  0.012060  0.012276  0.013677  0.013851
# topic_026  0.014976  0.013231  0.015989  0.013789  0.009926  0.012274
# topic_027  0.013141  0.014007  0.014877  0.011434  0.008586  0.010077
# topic_028  0.013438  0.015292  0.014872  0.013385  0.012300  0.009536
# topic_029  0.012552  0.016082  0.015035  0.013028  0.018621  0.014285
# ...             ...       ...       ...       ...       ...       ...
# topic_045  0.012951  0.015419  0.012769  0.010355  0.012391  0.014159
# topic_046  0.014207  0.014734  0.010631  0.012772  0.006635  0.013550
# topic_047  0.014603  0.017201  0.009094  0.015328  0.016156  0.018929
# topic_048  0.014708  0.014574  0.015073  0.012524  0.013473  0.013911
# topic_049  0.013491  0.015689  0.014475  0.013981  0.012766  0.012156
# topic_050  0.012298  0.012783  0.011904  0.014617  0.010570  0.011824
# topic_051  0.012362  0.012096  0.013099  0.014197  0.010321  0.012063
# topic_052  0.013434  0.016443  0.016043  0.016989  0.013588  0.017885
# topic_053  0.011772  0.017697  0.014010  0.015565  0.010880  0.012326
# topic_054  0.012860  0.015948  0.010445  0.011287  0.011372  0.012867
# topic_055  0.014135  0.015138  0.014550  0.012805  0.010647  0.013347
# topic_056  0.012941  0.014990  0.015538  0.014789  0.013644  0.011190
# topic_057  0.014808  0.013745  0.009112  0.010633  0.013870  0.012538
# topic_058  0.013624  0.013252  0.012705  0.014114  0.013679  0.014177
# topic_059  0.012360  0.015580  0.014604  0.012061  0.015482  0.014565
# topic_060  0.012937  0.010187  0.013431  0.013023  0.014949  0.012472
# topic_061  0.014707  0.010965  0.009675  0.015993  0.012722  0.014599
# topic_062  0.012342  0.010380  0.014300  0.015202  0.011340  0.013485
# topic_063  0.012581  0.012655  0.013192  0.015022  0.014381  0.013369
# topic_064  0.012482  0.014406  0.011630  0.014514  0.013506  0.010957
# topic_065  0.011376  0.008329  0.015478  0.014477  0.013931  0.016076
# topic_066  0.013578  0.012955  0.011212  0.012683  0.007785  0.011597
# topic_067  0.012875  0.013896  0.016709  0.011547  0.015746  0.017198
# topic_068  0.014548  0.010908  0.013830  0.012211  0.013725  0.010586
# topic_069  0.014949  0.011789  0.013007  0.013119  0.011440  0.016992
# topic_070  0.013673  0.017486  0.015866  0.011080  0.010935  0.017232
# topic_071  0.014719  0.011384  0.014947  0.009939  0.011296  0.011479
# topic_072  0.013800  0.014723  0.013013  0.013097  0.010343  0.013907
# topic_073  0.012930  0.009464  0.010793  0.016856  0.011132  0.015448
# topic_074  0.013090  0.013260  0.010326  0.014413  0.015793  0.014049
#
#              428006    428007    428008    428009  ...    212990    212991  \
# topic_000  0.014843  0.012608  0.015429  0.014403  ...  0.017879  0.009259
# topic_001  0.013641  0.012800  0.014577  0.012263  ...  0.014766  0.010151
# topic_002  0.017617  0.015060  0.014783  0.015208  ...  0.010701  0.013932
# topic_003  0.024115  0.012540  0.012588  0.012490  ...  0.008714  0.014285
# topic_004  0.022622  0.010747  0.013580  0.015798  ...  0.016124  0.009288
# topic_005  0.015245  0.014425  0.012430  0.009416  ...  0.013568  0.012891
# topic_006  0.006001  0.013939  0.013321  0.008567  ...  0.010831  0.010264
# topic_007  0.012693  0.014844  0.010592  0.014921  ...  0.012277  0.010991
# topic_008  0.014759  0.015699  0.010716  0.012206  ...  0.013743  0.014498
# topic_009  0.009586  0.013087  0.012404  0.010277  ...  0.014168  0.012926
# topic_010  0.009573  0.014322  0.013145  0.013043  ...  0.015018  0.012529
# topic_011  0.020890  0.014243  0.014339  0.009156  ...  0.012227  0.013348
# topic_012  0.009529  0.010327  0.015464  0.009354  ...  0.015089  0.013820
# topic_013  0.012900  0.015956  0.016986  0.008266  ...  0.012044  0.012988
# topic_014  0.004953  0.012062  0.010772  0.013278  ...  0.015304  0.013152
# topic_015  0.008785  0.011402  0.015886  0.011049  ...  0.013787  0.014252
# topic_016  0.012188  0.010756  0.012552  0.010745  ...  0.010374  0.015491
# topic_017  0.014409  0.014974  0.010916  0.017383  ...  0.017945  0.013180
# topic_018  0.010439  0.013448  0.013318  0.016783  ...  0.015329  0.010495
# topic_019  0.025847  0.012088  0.010915  0.010494  ...  0.009812  0.011654
# topic_020  0.016260  0.015107  0.013548  0.017906  ...  0.015076  0.011604
# topic_021  0.010434  0.013605  0.011814  0.019244  ...  0.010688  0.008700
# topic_022  0.013864  0.016314  0.012439  0.014628  ...  0.011005  0.014347
# topic_023  0.010580  0.014037  0.011825  0.011746  ...  0.011232  0.012960
# topic_024  0.011955  0.010903  0.012024  0.013033  ...  0.011689  0.015973
# topic_025  0.015897  0.015098  0.012830  0.018608  ...  0.011219  0.009419
# topic_026  0.019880  0.013272  0.014906  0.014525  ...  0.011715  0.009072
# topic_027  0.018287  0.011607  0.012380  0.010994  ...  0.015736  0.018332
# topic_028  0.010521  0.011548  0.014851  0.018400  ...  0.014296  0.011269
# topic_029  0.005853  0.015290  0.013656  0.006517  ...  0.011655  0.012735
# ...             ...       ...       ...       ...  ...       ...       ...
# topic_045  0.020929  0.011668  0.011419  0.010389  ...  0.016807  0.016005
# topic_046  0.013296  0.016875  0.013909  0.017689  ...  0.013273  0.010266
# topic_047  0.015689  0.012303  0.013602  0.012130  ...  0.016755  0.015337
# topic_048  0.015665  0.011519  0.013542  0.018061  ...  0.012522  0.009966
# topic_049  0.011069  0.016829  0.011492  0.017092  ...  0.011978  0.020573
# topic_050  0.011709  0.016163  0.013421  0.009469  ...  0.011161  0.012400
# topic_051  0.011001  0.010625  0.012959  0.010209  ...  0.015271  0.011953
# topic_052  0.019552  0.010715  0.012530  0.015693  ...  0.008847  0.011370
# topic_053  0.003512  0.017630  0.012472  0.015195  ...  0.012796  0.011956
# topic_054  0.010061  0.014972  0.012377  0.009634  ...  0.014898  0.014563
# topic_055  0.006457  0.011892  0.015156  0.020005  ...  0.013335  0.017220
# topic_056  0.018987  0.011795  0.015694  0.015430  ...  0.011748  0.012034
# topic_057  0.009929  0.012564  0.012884  0.011983  ...  0.010714  0.019470
# topic_058  0.015528  0.015234  0.013146  0.017327  ...  0.014181  0.013107
# topic_059  0.008088  0.011085  0.013884  0.009834  ...  0.011431  0.012536
# topic_060  0.007880  0.015245  0.013210  0.010792  ...  0.013627  0.014325
# topic_061  0.012390  0.012512  0.013571  0.012482  ...  0.016844  0.015097
# topic_062  0.011560  0.017095  0.015840  0.012460  ...  0.013167  0.008969
# topic_063  0.014142  0.010439  0.014239  0.013042  ...  0.015415  0.012242
# topic_064  0.019993  0.013710  0.012354  0.014003  ...  0.013050  0.017885
# topic_065  0.018609  0.014041  0.016329  0.012546  ...  0.015763  0.015986
# topic_066  0.009706  0.012802  0.015800  0.010460  ...  0.012778  0.015967
# topic_067  0.014198  0.015103  0.013740  0.013480  ...  0.011583  0.013047
# topic_068  0.011692  0.010343  0.010649  0.011252  ...  0.013061  0.012211
# topic_069  0.018140  0.013593  0.012282  0.008124  ...  0.012756  0.017224
# topic_070  0.009727  0.011106  0.013593  0.017518  ...  0.015205  0.015899
# topic_071  0.013679  0.015341  0.011311  0.015330  ...  0.011946  0.012392
# topic_072  0.010772  0.015337  0.011898  0.008307  ...  0.009522  0.015853
# topic_073  0.014367  0.011846  0.012055  0.010944  ...  0.017629  0.014113
# topic_074  0.017845  0.010429  0.014353  0.013165  ...  0.013987  0.016282
#
#              212992    212993    212994    212995    212996    212997  \
# topic_000  0.007029  0.013422  0.015026  0.015356  0.016973  0.011483
# topic_001  0.013001  0.014423  0.010776  0.015535  0.009773  0.013188
# topic_002  0.014679  0.011284  0.014534  0.010196  0.011373  0.012226
# topic_003  0.011181  0.012620  0.011971  0.012325  0.014297  0.012740
# topic_004  0.010397  0.014758  0.011695  0.011454  0.013270  0.014805
# topic_005  0.014674  0.015443  0.014248  0.011555  0.010379  0.012039
# topic_006  0.012201  0.014723  0.016591  0.014469  0.011503  0.018487
# topic_007  0.018392  0.012976  0.016425  0.008832  0.013144  0.010134
# topic_008  0.011680  0.011677  0.010774  0.012487  0.009969  0.014820
# topic_009  0.015355  0.014823  0.009050  0.015829  0.015742  0.010015
# topic_010  0.014740  0.014152  0.011151  0.015924  0.013761  0.017498
# topic_011  0.014926  0.011017  0.013870  0.018554  0.011652  0.016511
# topic_012  0.016030  0.009912  0.013937  0.013933  0.011582  0.016093
# topic_013  0.018323  0.016117  0.015548  0.013381  0.011199  0.007838
# topic_014  0.012871  0.012896  0.008563  0.013397  0.011582  0.011601
# topic_015  0.012375  0.018150  0.014852  0.013393  0.011234  0.010743
# topic_016  0.008259  0.013804  0.016537  0.017029  0.014323  0.014134
# topic_017  0.016818  0.012482  0.008109  0.014834  0.013399  0.012378
# topic_018  0.016443  0.010201  0.012922  0.013398  0.012653  0.009450
# topic_019  0.005085  0.010812  0.012667  0.010863  0.012495  0.015402
# topic_020  0.009233  0.015523  0.015424  0.012313  0.014259  0.014312
# topic_021  0.012882  0.011213  0.012912  0.012284  0.013415  0.011811
# topic_022  0.015913  0.012923  0.009156  0.012354  0.011213  0.018719
# topic_023  0.013321  0.011991  0.013797  0.013296  0.010384  0.014345
# topic_024  0.016863  0.014959  0.014647  0.014985  0.015475  0.015130
# topic_025  0.010131  0.015146  0.012700  0.012882  0.011782  0.016123
# topic_026  0.014617  0.010092  0.011784  0.010183  0.013501  0.014630
# topic_027  0.014645  0.012522  0.014472  0.012652  0.010690  0.018701
# topic_028  0.014530  0.016129  0.013333  0.017225  0.014741  0.010494
# topic_029  0.011258  0.015094  0.013785  0.015921  0.014213  0.013130
# ...             ...       ...       ...       ...       ...       ...
# topic_045  0.011466  0.018231  0.016110  0.011576  0.013654  0.015626
# topic_046  0.015620  0.016925  0.011276  0.015202  0.014472  0.010984
# topic_047  0.008477  0.013999  0.016617  0.011158  0.015838  0.014166
# topic_048  0.015490  0.011781  0.013383  0.014608  0.010175  0.012420
# topic_049  0.016931  0.016139  0.015111  0.011437  0.014719  0.014425
# topic_050  0.011056  0.013174  0.008694  0.016164  0.008509  0.015062
# topic_051  0.008222  0.012183  0.018372  0.016434  0.017827  0.009774
# topic_052  0.012432  0.012719  0.014904  0.013456  0.014713  0.012793
# topic_053  0.011956  0.010476  0.014939  0.011346  0.012254  0.011730
# topic_054  0.014192  0.016351  0.011500  0.014652  0.013104  0.011936
# topic_055  0.016685  0.009541  0.012944  0.011524  0.016024  0.016215
# topic_056  0.012804  0.015092  0.010686  0.012665  0.013556  0.008626
# topic_057  0.016692  0.016328  0.011073  0.010396  0.014086  0.011113
# topic_058  0.009733  0.012443  0.013818  0.014375  0.012412  0.014617
# topic_059  0.018212  0.019298  0.014237  0.014728  0.016543  0.014340
# topic_060  0.011900  0.010135  0.011467  0.014144  0.016190  0.016446
# topic_061  0.016583  0.015958  0.017521  0.012509  0.017814  0.011679
# topic_062  0.013620  0.012395  0.012919  0.013011  0.015209  0.013268
# topic_063  0.007194  0.017639  0.010805  0.017410  0.011922  0.015973
# topic_064  0.013659  0.014442  0.013928  0.010525  0.011615  0.010256
# topic_065  0.009748  0.010347  0.017165  0.011461  0.013421  0.011319
# topic_066  0.012869  0.011777  0.013409  0.013046  0.013032  0.012025
# topic_067  0.011520  0.015133  0.011349  0.012080  0.012157  0.015216
# topic_068  0.010479  0.009825  0.013915  0.012249  0.010081  0.011448
# topic_069  0.015745  0.010700  0.014081  0.013043  0.010365  0.017762
# topic_070  0.011917  0.013686  0.011827  0.011491  0.015102  0.015428
# topic_071  0.018946  0.014401  0.013783  0.012085  0.011863  0.013561
# topic_072  0.016283  0.009740  0.011468  0.016892  0.013988  0.014406
# topic_073  0.015197  0.011611  0.011742  0.014291  0.009999  0.014346
# topic_074  0.011964  0.010646  0.011169  0.010104  0.016522  0.012301
#
#              212998    212999
# topic_000  0.013170  0.014008
# topic_001  0.012635  0.011314
# topic_002  0.012478  0.011413
# topic_003  0.014263  0.016657
# topic_004  0.017678  0.019322
# topic_005  0.012075  0.012164
# topic_006  0.013947  0.013139
# topic_007  0.012728  0.012793
# topic_008  0.014254  0.013522
# topic_009  0.013741  0.011929
# topic_010  0.012308  0.010830
# topic_011  0.015122  0.014296
# topic_012  0.013879  0.010407
# topic_013  0.012206  0.012315
# topic_014  0.015645  0.013998
# topic_015  0.013924  0.011927
# topic_016  0.010639  0.014663
# topic_017  0.010073  0.014144
# topic_018  0.014992  0.010767
# topic_019  0.014284  0.010728
# topic_020  0.015084  0.019412
# topic_021  0.012088  0.014764
# topic_022  0.013765  0.014156
# topic_023  0.016023  0.007949
# topic_024  0.015763  0.013546
# topic_025  0.012992  0.016454
# topic_026  0.010925  0.012943
# topic_027  0.015326  0.015046
# topic_028  0.014516  0.011035
# topic_029  0.011513  0.014813
# ...             ...       ...
# topic_045  0.015601  0.015160
# topic_046  0.012943  0.010099
# topic_047  0.016521  0.013334
# topic_048  0.013820  0.014642
# topic_049  0.013192  0.008853
# topic_050  0.016402  0.014115
# topic_051  0.014568  0.014829
# topic_052  0.014095  0.013072
# topic_053  0.014345  0.014337
# topic_054  0.013947  0.013961
# topic_055  0.013440  0.014808
# topic_056  0.009859  0.014507
# topic_057  0.011002  0.017703
# topic_058  0.013905  0.016128
# topic_059  0.012183  0.014843
# topic_060  0.012969  0.015475
# topic_061  0.012114  0.010544
# topic_062  0.014279  0.013471
# topic_063  0.013653  0.009179
# topic_064  0.013704  0.009234
# topic_065  0.012635  0.011138
# topic_066  0.015742  0.015735
# topic_067  0.011433  0.015776
# topic_068  0.015426  0.012439
# topic_069  0.011721  0.011226
# topic_070  0.014318  0.011667
# topic_071  0.008657  0.011462
# topic_072  0.014360  0.013451
# topic_073  0.011547  0.012760
# topic_074  0.016674  0.010636
#
# [75 rows x 994326 columns]
